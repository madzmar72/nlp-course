# %% [markdown]
# # INFO 159/259
# #<center> Homework 5: Information Extraction </center>
#
# <center> Due: April 6, 2026 @ 11:59pm </center>

# %% [markdown]
# In this assignment, we'll examine how one could use **bootstrapping** to extract relations between entities from a dataset.
#
# Imagine you have been appointed to manage a large and ecologically diverse preserve. Here, the wifi is shaky, and the cell service is non-existent. It'll be a nice respite from trudging through endless midterms at Berkeley.
#
# However, this morning, a group of long-tailed macques ambushed you and stole your paper records detailing a taxonomy of the animals. You're left in a troubling situation, as without this taxonomy, it's tough to know which animals are which types and properly care for them. What are giraffes? Cephalopods? You're not too sure.
#
# The zoologists are on vacation, and have only left behind a collection of long-form notes describing the animals. Your only hope is to use relation extraction methods from INFO 159/259 to restructure these notes and get a head start on rebuilding the stolen taxonomy.

# %% [markdown]
# Your knowledge of animals is pretty flimsy. Luckily, you recall from [Jurafsky & Martin Chapter 20](https://web.stanford.edu/~jurafsky/slp3/20.pdf) the following algorithm for bootstrapping:
#
# ```
# function BOOTSTRAP(Relation_R) returns new_relation_tuples
#   tuples ← Gather a set of seed tuples that have relation R
#   iterate
#     sentences ← find sentences that contain entities in tuples
#     patterns ← generalize the context between and around entities in sentences
#     new_pairs ← use patterns to identify more tuples
#     new_pairs ← new_pairs with high confidence
#     tuples ← tuples + new_pairs
#   return tuples
# ```

# %% [markdown]
# We'll demonstrate the affordances and caveats of this algorithm by walking through one iteration. We'll gather phrases that are suggestive of *is-a* relations between animals and their types, and recover new hyponym-hypernym pairs to save the day.

# %% [markdown]
# > **Only** modify text or code in between `### BEGIN SOLUTION` and `### END SOLUTION` lines. There are also some "Consider" questions; answer these to earn full credit.

# %%
# !pip install dafsa
# Out:
# Collecting dafsa
#   Downloading dafsa-1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from dafsa) (3.6.1)
# Downloading dafsa-1.0-py3-none-any.whl (19 kB)
# Installing collected packages: dafsa
# Successfully installed dafsa-1.0

# %%
import itertools
from collections import defaultdict, Counter
from tqdm import tqdm
import networkx as nx
from dafsa import DAFSA
import re
import random

# %% [markdown]
# # Introduction

# %% [markdown]
# ### **Learning Objectives**
# In this homework, you will:
# - mine for patterns through transforming pre-processed text into tuples
# - understand the process of Relation Extraction and how semantic drift may be accounted for using bootstrapping

# %% [markdown]
# You think it's a bit wild (pun intended) that the records at this animal preserve are still all on paper. You digitize the zoologists' handwritten notes, and preprocess your dataset to include token indices of nouns that refer to animals in your nature preserve (ANIMAL), and token indices of other nouns detected by a spaCy POS tagger (NOUN).
#
# Download this digitized file of pre-tagged notes by running the following cell.

# %%
# !wget https://github.com/dbamman/nlp-course/raw/refs/heads/main/HW/data/tagged_sentences.txt -O tagged_sentences.txt
# Out:
# --2026-04-06 21:44:44--  https://github.com/dbamman/nlp-course/raw/refs/heads/main/HW/data/tagged_sentences.txt
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dbamman/nlp-course/refs/heads/main/HW/data/tagged_sentences.txt [following]
# --2026-04-06 21:44:44--  https://raw.githubusercontent.com/dbamman/nlp-course/refs/heads/main/HW/data/tagged_sentences.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6290129 (6.0M) [text/plain]
# Saving to: ‘tagged_sentences.txt’
#
# tagged_sentences.tx 100%[===================>]   6.00M  --.-KB/s    in 0.05s
#
# 2026-04-06 21:44:45 (113 MB/s) - ‘tagged_sentences.txt’ saved [6290129/6290129]

# %% [markdown]
# In this tab-delimited file,
# 1. the first column is the lemmatized name of an animal,
# 2. the second column is a sentence, and
# 3. the third column is a tokenized, lemmatized form of that sentence.
#
# The remaining columns are indices of animals and non-target-animal nouns in the sentence.

# %%
with open('tagged_sentences.txt', 'r') as infile:
  for line in infile:
    print(line.strip().split('\t')) # view each column
    break
# Out:
# ['horse', 'The horse is a domesticated, one-toed, hoofed mammal.', 'the horse be a domesticate , one - toed , hoofed mammal .', 'ANIMAL 1', 'NOUN 11']

# %% [markdown]
# Here are all animal *is-a* relations that you can remember right now. This is your set of seed tuples for bootstrapping.

# %%
seed_tuples = [('kangaroo', 'marsupial'), ('kangaroo', 'mammal'), ('horse', 'mammal'), ('toucan', 'bird'),
                ('crocodile', 'reptile'), ('ant', 'anthropod'), ('dinosaur', 'reptile'), ('hawk', 'bird'),
                ('eagle', 'bird'), ('lark', 'bird'), ('toad', 'amphibian'), ('frog', 'amphibian'), ('ibis', 'bird'),
                ('oyster', 'shellfish'), ('pigeon', 'bird'), ('shark', 'fish'), ('hummingbird', 'bird'),
                ('jellyfish', 'cnidarian'), ('octopus', 'cephalopod'), ('anteater', 'xenarthan'), ('moose', 'mammal'),
                ('dragonfly', 'insect'), ('camel', 'mammal'), ('beetle', 'insect'), ('kinkajou', 'mammal'), ('alpaca', 'mammal')]

# %% [markdown]
# # Deliverables

# %% [markdown]
# ## Mining for patterns
#
# Let's find sentences in the zoologists' notes that contain our seed set of `(ANIMAL, NOUN)` tuples, and extract the context around them.
#
# Each phrasal pattern has three key parts:
# - the middle context between one 'ANIMAL' and one 'NOUN'
# - a left context of at most $n$ space-separated tokens to the left
# - a right context of at most $m$ space-separated tokens to the right.

# %% [markdown]
# For example, here are some phrasal patterns with $n=2$ and $m=2$:
#
# - `the ANIMAL be a NOUN .` ← "The giraffe is a mammal.",
# - `as a NOUN , a ANIMAL have fur` ← "As a mammal, a giraffe has fur.".

# %% [markdown]
# ### To-Do
#
# Implement the following function that takes in token indices of an `(ANIMAL, NOUN)` pair and a preprocessed sentence from your zoologists' notes. The output is a phrasal pattern.
#
# For example, given the preprocessed (lemmatized & tokenized) sentence
#
# ```
# ['tall', 'and', 'long', '-', 'neck', ',', 'the', 'giraffe', 'be', 'a', 'mammal', ',', 'and', 'it', 'eat', 'leaf', 'from', 'high', 'branch', 'of', 'tree', '.']
# ```
#
# and indices of `('giraffe', 'mammal')` as `(7, 10)`, and $n=2$ and $m=2$, your function should output
#
# ```
# , the ANIMAL be a NOUN , and
# ```
#
# With $n=5$ and $m=5$, your function should instead output
#
# ```
# long - neck , the ANIMAL be a NOUN , and it eat leaf
# ```

# %%
def transform_text_into_pattern(animal_noun, tokenized_sentence, n, m):
  '''
  @inputs:
  - animal_noun: a tuple of (ANIMAL, NOUN) indices
    For example, in the sentence "The horse is a domesticated, one-toed, hoofed mammal.",
    animal_noun == (1, 11),
    where token index 1 is "horse" and token index 11 is "mammal".
  - tokenized_sentence: a lemmatized, tokenized sentence, represented as a list of tokens
  - n: an integer indicating the size, or number of tokens, of the left context window
  - m: an integer indicating the size, or number of tokens, of the right content window

  @outputs:
  - phrase: a string containing left, middle, and right context around ANIMAL and NOUN
  '''
  phrase = ''
  animal_idx = animal_noun[0]
  noun_idx = animal_noun[1]
  ### BEGIN SOLUTION
  #middle context
  middle = ''
  if animal_idx < noun_idx:
    for i in range(animal_idx+1, noun_idx):
      middle+=tokenized_sentence[i]
      middle+=' '
  else:
    for i in range(noun_idx+1, animal_idx):
      middle+=tokenized_sentence[i]
      middle+=' '

  #beginning context
  beginning = ''
  if animal_idx < noun_idx:
    start_idx = max(animal_idx - n,0)
    for i in range(start_idx, animal_idx):
      beginning+=tokenized_sentence[i]
      beginning+=' '
  else:
    start_idx = max(0, noun_idx - n)
    for i in range(start_idx, noun_idx):
      beginning+=tokenized_sentence[i]
      beginning+=' '

  #end context
  end = ''
  if animal_idx < noun_idx:
    end_idx = min(noun_idx+m, len(tokenized_sentence)-1)
    for i in range(noun_idx+1, end_idx+1):
      end+=tokenized_sentence[i]
      end+= ' '
  else:
    end_idx=min(animal_idx+m, len(tokenized_sentence)-1)
    for i in range(animal_idx+1, end_idx+1):
      end+=tokenized_sentence[i]
      end+=' '
  ### END SOLUTION
  if animal_idx < noun_idx:
    phrase = beginning + 'ANIMAL' + ' ' + middle + 'NOUN' + ' ' + end
  else:
    phrase = beginning + 'NOUN' + ' ' + middle + 'ANIMAL' + ' ' + end
  return phrase.strip()

# %% [markdown]
# Check that your function works as expected by running the following cell.

# %%
phrase = transform_text_into_pattern((1, 4),
      ['the', 'giraffe', 'be', 'a', 'mammal', '.'], 5, 5)
assert(phrase == 'the ANIMAL be a NOUN .')

phrase = transform_text_into_pattern((7, 10),
      ['tall', 'and', 'long', '-', 'neck', ',', 'the', 'giraffe', 'be', 'a',
       'mammal', ',', 'and', 'it', 'eat', 'leaf', 'from', 'high',
       'branch', 'of', 'tree', '.'], 5, 5)
assert(phrase == 'long - neck , the ANIMAL be a NOUN , and it eat leaf')

phrase = transform_text_into_pattern((7, 10),
      ['tall', 'and', 'long', '-', 'neck', ',', 'the', 'giraffe', 'be', 'a',
       'mammal', ',', 'and', 'it', 'eat', 'leaf', 'from', 'high',
       'branch', 'of', 'tree', '.'], 2, 2)
assert(phrase == ', the ANIMAL be a NOUN , and')

phrase = transform_text_into_pattern((5, 2),
      ['as', 'a', 'mammal', ',', 'a', 'giraffe', 'have', 'fur'], 5, 5)
assert(phrase == 'as a NOUN , a ANIMAL have fur')

# %% [markdown]
# Now, we call your function to extract phrasal patterns based on the seed set of tuples. To keep things tidy, we restrict the middle context to be $\leq 10$ tokens long.

# %%
def parse_input_line(line):
  contents = line.strip().split('\t')
  animal = contents[0]
  sentence = contents[1]
  sentence_toks = contents[2].split(' ')

  # get animal and noun indices
  animal_idx = []
  noun_idx = []
  for i in range(3, len(contents)):
    if contents[i].startswith('ANIMAL'):
      animal_idx.append(int(contents[i].split()[-1]))
    elif contents[i].startswith('NOUN'):
      noun_idx.append(int(contents[i].split()[-1]))
  return animal, sentence, sentence_toks, animal_idx, noun_idx

def extract_phrasal_patterns(seed_tuples):
  '''
  @inputs:
  - seed_tuples: a set of seed tuples of (ANIMAL, NOUN)

  @outputs:
  - phrasal_patterns: a dictionary of patterns to their original sentences
  '''
  phrasal_patterns = defaultdict(list)

  with open('tagged_sentences.txt', 'r') as infile:
    for line in tqdm(infile, total=19587):
      animal, sentence, sentence_toks, animal_idx, noun_idx = parse_input_line(line)

      # get phrasal contexts of animal and noun pairs
      for pair in itertools.product(animal_idx, noun_idx):
        if (sentence_toks[pair[0]], sentence_toks[pair[1]]) in seed_tuples:
          if abs(pair[0] - pair[1]) <= 10:
            # calls the function that you wrote
            phrase = transform_text_into_pattern(pair, sentence_toks, 5, 5)
            phrasal_patterns[phrase].append(sentence)

  return phrasal_patterns

# %%
phrasal_patterns = extract_phrasal_patterns(seed_tuples)
# Out:
# 100%|██████████| 19587/19587 [00:00<00:00, 83722.97it/s]

# %%
pattern = 'the ANIMAL be a domesticate , one - toed , hoofed NOUN .'
print(phrasal_patterns[pattern])
# this cell should print out "['The horse is a domesticated, one-toed, hoofed mammal.']"
# Out:
# ['The horse is a domesticated, one-toed, hoofed mammal.']

# %% [markdown]
# It is good to *generalize* the context around target entities, to account for irrelevant contextual variations. There are many ways one could approach this. Here, we'll replace infrequent parts of contexts with a wildcard `*`.

# %% [markdown]
# We implement pattern generalization for you. To do so, we construct a directed acyclic word graph by looping through all of the phrasal patterns our seed tuples found. Each edge of this graph represents one word (unlike [the example figure on Wikipedia](https://en.wikipedia.org/wiki/Deterministic_acyclic_finite_state_automaton), where each edge is a letter/character). Each path starting at the root of this graph is a phrasal pattern, and edge weights are incremented based on how often they are traversed across all patterns. If an edge appears less than 3 times, it is replaced with a `*`.  Our implementation is heavily inspired by Section 3.3 of [this paper](https://arxiv.org/abs/1804.02525).
#
# For example, the sentences "_**Giraffes** are large African hoofed **mammals** who eats leaves._" and "_**Giraffes** are tall **mammals** living in grassy, open woodlands._" could be both represented by the pattern `ANIMAL be * NOUN *`.

# %%
def build_graph(phrasal_patterns):
    """
    Builds a directed word graph from a set of phrasal patterns.
    Each word is weighted by its count in the graph.

    @input:

    @output:
    - a networkx graph
    """
    words = []
    for pattern in phrasal_patterns:
        words.append(pattern.split(' '))
    d = DAFSA(words) # creates directed acyclic word graphs

    # convert d into a networkx graph that is directed and has parallel edges
    graph = nx.MultiDiGraph()
    for node_id, node in d.nodes.items():
      graph.add_node(node_id)
      graph.nodes[node_id]["final"] = node.final

    for left in d.nodes.values():
        for label, right in left.edges.items():
            l_id = left.node_id
            r_id = right.node.node_id
            graph.add_edge(l_id, r_id, weight=right.weight, label=label)

    return graph

def clean_up_patterns(all_patterns):
  clean_patterns = set()
  for pattern in all_patterns:
    pattern_string = ' '.join(pattern)
    # reduce repeated * into a single *
    pattern_string = re.sub(r'(\*\s?)+', '* ', pattern_string)
    # constraint: some middle context must exist
    if 'ANIMAL * NOUN' in pattern_string or 'NOUN * ANIMAL' in pattern_string:
      continue
    clean_patterns.add(pattern_string.strip())
  clean_patterns = list(clean_patterns)
  return clean_patterns

def get_generalized_paths(graph):
  '''
  @inputs:
  - a networkx graph

  @outputs:
  - generalized phrasal patterns, as strings
  '''
  final_nodes = []
  for node in graph.nodes(data=True):
    if node[1]['final']:
      final_nodes.append(node[0])
  weight_threshold = 3 # number of times a transition/edge must exist for us to not wildcard it
  do_not_wildcard = ['ANIMAL', 'NOUN'] # tokens that shouldn't be replaced with a wildcard

  clustered_patterns = []
  for end in final_nodes:
    paths = nx.all_simple_edge_paths(graph, 0, end)
    for path in paths:
      this_path = []
      for edge in path:
          src = edge[0]
          dst = edge[1]
          edge_data = graph.get_edge_data(edge[0], edge[1])[edge[2]]
          if edge_data['label'] not in do_not_wildcard and \
              edge_data['weight'] < weight_threshold:
            this_path.append('*')
          else:
            this_path.append(edge_data['label'])
      clustered_patterns.append(this_path)

  clustered_patterns = clean_up_patterns(clustered_patterns)
  clustered_patterns = sorted(clustered_patterns)
  return clustered_patterns

# %%
graph = build_graph(phrasal_patterns)
clustered_patterns = get_generalized_paths(graph)

# %%
clustered_patterns
# Out:
# ['ANIMAL , like * NOUN *',
#  'ANIMAL , like other * NOUN *',
#  'ANIMAL , like other * NOUN * be',
#  'ANIMAL , like other NOUN *',
#  'ANIMAL be * NOUN *',
#  'ANIMAL be * NOUN * .',
#  'ANIMAL be * NOUN * specie',
#  'ANIMAL be NOUN *',
#  'ANIMAL be NOUN * .',
#  'ANIMAL be NOUN * and',
#  'ANIMAL be the * NOUN *',
#  'ANIMAL be the * NOUN * specie',
#  'ANIMAL be the * NOUN .',
#  'like most NOUN , * ANIMAL *',
#  'like most NOUN , ANIMAL * and',
#  'like most NOUN , ANIMAL * the',
#  'like other NOUN , * ANIMAL *',
#  'like other NOUN , ANIMAL *',
#  'like other NOUN , ANIMAL * ,',
#  'like other NOUN , ANIMAL * as',
#  'the ANIMAL be a * NOUN *',
#  'the ANIMAL be a * NOUN .',
#  'unlike other NOUN , * ANIMAL * and',
#  'unlike other NOUN , ANIMAL *',
#  'unlike other NOUN , ANIMAL * be']

# %% [markdown]
# As a sanity check for your implementation, the above cell should output patterns containing n-grams such as "like other NOUN", "like most NOUN", "ANIMAL be", and "unlike other NOUN".
#
# You may notice that some of these patterns are subsets of others. The extent to which we rely on `*` to be a catch-all for the context around ANIMAL and potential NOUNs affects precision, as we'll soon see.

# %% [markdown]
# ## Identify more animal-type tuples
#
# Now, let's use these patterns to find more potential *is-a* relations for the animals in our preserve.

# %% [markdown]
# ### To-Do
#
# Your task is to write a function that takes in a candidate phrase containing ANIMAL and NOUN, and checks whether it matches with a pattern we mined above. Hint: use the regex package `re`.

# %%
def is_match(cand_phrase, pattern):
  '''
  @input:
  - cand_phrase: a candidate phrase containing ANIMAL and NOUN, e.g. "like other NOUN , the ANIMAL eat hay ."
  - pattern: a generalized pattern, e.g. "like other NOUN , * ANIMAL *"

  @output:
  - a boolean of True or False
  '''
  ### BEGIN SOLUTION
  adjusted_pattern = re.escape(pattern) #neutralize characters
  adjusted_asterisk = adjusted_pattern.replace(r'\*', '.*') #make asterisk into regex command
  return bool(re.fullmatch(adjusted_asterisk, cand_phrase)) #regex command to compare
  ### END SOLUTION

# %% [markdown]
# Test out your implementation by running the following cell.

# %%
print('--- Test Case 1 ---')
cand_phrase_1 = "like other NOUN , the ANIMAL eat hay ."
pattern_1 = "like other NOUN , * ANIMAL *"
output = is_match(cand_phrase_1, pattern_1)
print(f"Candidate Phrase: '{cand_phrase_1}'")
print(f"Pattern: '{pattern_1}'")
print(f"is_match result: {output}")
assert output == True

print('\n--- Test Case 2 ---')
cand_phrase_2 = "like other NOUN , ANIMAL eat hay ."
pattern_2 = "like other NOUN , * ANIMAL *"
output = is_match(cand_phrase_2, pattern_2)
print(f"Candidate Phrase: '{cand_phrase_2}'")
print(f"Pattern: '{pattern_2}'")
print(f"is_match result: {output}")
assert output == False

print('\n--- Test Case 3 ---')
cand_phrase_3 = "like other NOUN , ANIMAL eat hay ."
pattern_3 = "like other NOUN , ANIMAL *"
output = is_match(cand_phrase_3, pattern_3)
print(f"Candidate Phrase: '{cand_phrase_3}'")
print(f"Pattern: '{pattern_3}'")
print(f"is_match result: {output}")
assert output == True

print('\n--- Test Case 4 ---')
cand_phrase_4 = "ANIMAL be a domesticate , one - toed , hoofed NOUN ."
pattern_4 = "ANIMAL be * NOUN *"
output = is_match(cand_phrase_4, pattern_4)
print(f"Candidate Phrase: '{cand_phrase_4}'")
print(f"Pattern: '{pattern_4}'")
print(f"is_match result: {output}")
assert output == True
# Out:
# --- Test Case 1 ---
# Candidate Phrase: 'like other NOUN , the ANIMAL eat hay .'
# Pattern: 'like other NOUN , * ANIMAL *'
# is_match result: True
#
# --- Test Case 2 ---
# Candidate Phrase: 'like other NOUN , ANIMAL eat hay .'
# Pattern: 'like other NOUN , * ANIMAL *'
# is_match result: False
#
# --- Test Case 3 ---
# Candidate Phrase: 'like other NOUN , ANIMAL eat hay .'
# Pattern: 'like other NOUN , ANIMAL *'
# is_match result: True
#
# --- Test Case 4 ---
# Candidate Phrase: 'ANIMAL be a domesticate , one - toed , hoofed NOUN .'
# Pattern: 'ANIMAL be * NOUN *'
# is_match result: True

# %%
def get_candidates():
  '''
  @outputs:
  - candidates: a list of (phrase, animal, noun), e.g. ('the ANIMAL be a domesticate , one - toed , hoofed NOUN .', 'horse', 'mammal')
  '''
  candidates = []
  with open('tagged_sentences.txt', 'r') as infile:
    for line in tqdm(infile, total=19587):
      animal, sentence, sentence_toks, animal_idx, noun_idx = parse_input_line(line)

      # get phrasal contexts of animal and noun pairs
      for pair in itertools.product(animal_idx, noun_idx):
        if abs(pair[0] - pair[1]) <= 10:
          # calls the function that you wrote
          phrase = transform_text_into_pattern(pair, sentence_toks, 5, 5)
          candidates.append((phrase, sentence_toks[pair[0]], sentence_toks[pair[1]]))
  return candidates

def filter_for_matches(candidates, clustered_patterns):
  matches = defaultdict(list)
  for cand in tqdm(candidates):
    for pattern in clustered_patterns:
      if is_match(cand[0], pattern):
        matches[pattern].append(cand)
  return matches

# %%
candidates = get_candidates()
matches = filter_for_matches(candidates, clustered_patterns)
# Out:
# 100%|██████████| 19587/19587 [00:00<00:00, 28199.82it/s]
# 100%|██████████| 63573/63573 [00:07<00:00, 8483.75it/s]

# %% [markdown]
# ### To-Do
#
# You remember from [Jurafsky & Martin Ch. 20](https://web.stanford.edu/~jurafsky/slp3/20.pdf), page 8 that
# > Bootstrapping systems also assign confidence values to new tuples to avoid semantic drift. In semantic drift, an erroneous pattern leads to the introduction of erroneous tuples, which, in turn, lead to the creation of problematic patterns and the meaning of the extracted relations ‘drifts’.
#
# > Confidence values for patterns are based on balancing two factors: the pattern’s performance with respect to the current set of tuples and the pattern’s productivity in terms of the number of matches it produces in the document collection.

# %% [markdown]
# With the above in mind, write the following function, `hits_and_finds()`, which returns the following:
# - `num_hits`: the number of unique (ANIMAL, NOUN) tuples in our seed set (`seed_tuples`) that a pattern $p$ matches while looking in our dataset.
# - `num_finds`: the total number of unique (ANIMAL, NOUN) tuples that $p$ finds in our dataset.

# %%
def hits_and_finds(matches, p, seed_tuples):
  '''
  @inputs:
  - matches: a dictionary of the format {generalized pattern: [list of tuples (preprocessed sentence, animal, noun) ] }
  - p: a generalized pattern
  - seed_tuples: a list of seed tuples of the format (animal, noun)

  @outputs:
  - num_hits: an int, or the number of unique seed animal-type tuples found by p
  - num_finds: an int, or the total number of unique animal-type tuples found by p
  '''
  assert p in matches

  ### BEGIN SOLUTION
  #num_finds
  pairs_set = set()
  match_tuples = matches[p]
  for current_tuple in match_tuples:
    pair = (current_tuple[1], current_tuple[2])
    pairs_set.add(pair)
  num_finds = len(pairs_set)
  #num_hits
  num_hits = 0
  for current_tuple in seed_tuples:
    if current_tuple in pairs_set:
      num_hits+=1


  ### END SOLUTION

  return num_hits, num_finds

# %% [markdown]
# Sanity check the implementation of your function with the following toy inputs.

# %%
matches_toy = {
    'the ANIMAL be a * NOUN *' : [
              ('the ANIMAL be a domesticate , one - toed , hoofed NOUN .',
               'horse',
               'mammal'),
              ('the ANIMAL be a medium - sized NOUN species that be often slightly',
               'mallard',
               'waterfowl'),
              ('the ANIMAL be a social NOUN , form pack of two',
               'meerkat',
               'mammal'),
              ('the ANIMAL be a NOUN .',
               'horse',
               'mammal'),
              ]
}
p_toy = 'the ANIMAL be a * NOUN *'
seed_tuples_toy = [('horse', 'mammal'), ('mallard', 'waterfowl'), ('toucan', 'bird')]

num_hits, num_finds = hits_and_finds(matches_toy, p_toy, seed_tuples_toy)
assert num_hits == 2 # because we hit ('horse', 'mammal') and ('mallard', 'waterfowl')
assert num_finds == 3 # because we find ('horse', 'mammal'), ('mallard', 'waterfowl'), and ('meerkat', 'mammal')

# %% [markdown]
# Let's inspect phrasal patterns and the `(ANIMAL, NOUN)` tuples they surface. For each pattern, we'll give examples of both hits and *new* finds.

# %%
def show_results(matches, seed_tuples):
  '''
  Prints candidate animal-type tuples and the patterns
  that identified them.
  '''
  for pattern in sorted(matches.keys()):
    num_hits, num_finds = hits_and_finds(matches, pattern, seed_tuples)
    hits = []
    new_finds = []
    for tup in matches[pattern]:
      animal_type = (tup[1], tup[2])
      if animal_type in seed_tuples:
        hits.append(tup)
      else:
        new_finds.append(tup)
    if len(new_finds) > 20:
      new_finds = random.sample(new_finds, 20)

    random.seed(0)
    print("Pattern:", pattern)
    print("# of hits: ", num_hits)
    print("Hits:")
    for tup in hits:
      print('\t', tup[1], 'is a', tup[2], '←', tup[0])
    print("# of new finds: ", num_finds - num_hits)
    print("Examples of new finds:")
    if len(new_finds) == 0:
      print("\tNone")
    for tup in new_finds:
      print('\t', tup[1], 'is a', tup[2], '←', tup[0])
    print('\n---------------------------------\n')

# %% [markdown]
# Scroll through the output of the following cell.

# %%
show_results(matches, seed_tuples)
# Out:
# Pattern: ANIMAL , like * NOUN *
# # of hits:  4
# Hits:
# 	 anteater is a xenarthan ← ANIMAL , like other NOUN , display several adaptation that
# 	 octopus is a cephalopod ← ANIMAL , like other coleoid NOUN but unlike more basal cephalopod
# 	 octopus is a cephalopod ← ANIMAL , like other coleoid cephalopod but unlike more basal NOUN or other mollusc , be
# 	 hawk is a bird ← ANIMAL , like most NOUN , be tetrachromat with four
# 	 toad is a amphibian ← ANIMAL , like many NOUN , exhibit breeding site fidelity
# # of new finds:  26
# Examples of new finds:
# 	 goose is a formation ← ANIMAL , like other bird , fly in a v NOUN .
# 	 toad is a site ← ANIMAL , like many amphibian , exhibit breeding NOUN fidelity .
# 	 anteater is a adaptation ← ANIMAL , like other xenarthan , display several NOUN that lead to very low
# 	 bear is a nation ← ANIMAL , like other animal , may symbolize NOUN .
# 	 turtle is a ability ← ANIMAL , like other reptile , have a limit NOUN to regulate their body temperature
# 	 lobster is a blood ← ANIMAL , like snail and spider , have blue NOUN due to the presence of
# 	 lobster is a spider ← ANIMAL , like snail and NOUN , have blue blood due
# 	 toad is a fidelity ← ANIMAL , like many amphibian , exhibit breeding site NOUN .
# 	 spider is a arachnid ← ANIMAL , like most other NOUN , keep at least four
# 	 hawk is a type ← ANIMAL , like most bird , be tetrachromat with four NOUN of colour receptor in the
# 	 goose is a v ← ANIMAL , like other bird , fly in a NOUN formation .
# 	 octopus is a coleoid ← ANIMAL , like other NOUN cephalopod but unlike more basal
# 	 porpoise is a blowhole ← ANIMAL , like other odontocete , possess only one NOUN .
# 	 budgerigar is a specie ← ANIMAL , like many other NOUN of parrot , be able
# 	 porpoise is a odontocete ← ANIMAL , like other NOUN , possess only one blowhole
# 	 hare is a leporid ← ANIMAL , like all NOUN , have jointed , or
# 	 moth is a bee ← ANIMAL , like butterfly , NOUN and other more popularly recognize
# 	 budgerigar is a parrot ← ANIMAL , like many other specie of NOUN , be able to mimic
# 	 goose is a bird ← ANIMAL , like other NOUN , fly in a v
# 	 turtle is a reptile ← ANIMAL , like other NOUN , have a limit ability
#
# ---------------------------------
#
# Pattern: ANIMAL , like other * NOUN *
# # of hits:  1
# Hits:
# 	 octopus is a cephalopod ← ANIMAL , like other coleoid NOUN but unlike more basal cephalopod
# 	 octopus is a cephalopod ← ANIMAL , like other coleoid cephalopod but unlike more basal NOUN or other mollusc , be
# # of new finds:  7
# Examples of new finds:
# 	 bear is a nation ← ANIMAL , like other animal , may symbolize NOUN .
# 	 porpoise is a blowhole ← ANIMAL , like other odontocete , possess only one NOUN .
# 	 wolverine is a molar ← ANIMAL , like other mustelid , possess a special upper NOUN in the back of the
# 	 turtle is a ability ← ANIMAL , like other reptile , have a limit NOUN to regulate their body temperature
# 	 goose is a v ← ANIMAL , like other bird , fly in a NOUN formation .
# 	 goose is a formation ← ANIMAL , like other bird , fly in a v NOUN .
# 	 anteater is a adaptation ← ANIMAL , like other xenarthan , display several NOUN that lead to very low
#
# ---------------------------------
#
# Pattern: ANIMAL , like other * NOUN * be
# # of hits:  1
# Hits:
# 	 octopus is a cephalopod ← ANIMAL , like other coleoid cephalopod but unlike more basal NOUN or other mollusc , be
# # of new finds:  0
# Examples of new finds:
# 	None
#
# ---------------------------------
#
# Pattern: ANIMAL , like other NOUN *
# # of hits:  1
# Hits:
# 	 anteater is a xenarthan ← ANIMAL , like other NOUN , display several adaptation that
# # of new finds:  6
# Examples of new finds:
# 	 bear is a animal ← ANIMAL , like other NOUN , may symbolize nation .
# 	 porpoise is a odontocete ← ANIMAL , like other NOUN , possess only one blowhole
# 	 wolverine is a mustelid ← ANIMAL , like other NOUN , possess a special upper
# 	 turtle is a reptile ← ANIMAL , like other NOUN , have a limit ability
# 	 goose is a bird ← ANIMAL , like other NOUN , fly in a v
# 	 octopus is a coleoid ← ANIMAL , like other NOUN cephalopod but unlike more basal
#
# ---------------------------------
#
# Pattern: ANIMAL be * NOUN *
# # of hits:  9
# Hits:
# 	 dinosaur is a reptile ← ANIMAL be a diverse group of NOUN of the clade Dinosauria .
# 	 dragonfly is a insect ← ANIMAL be predatory NOUN , both in their aquatic
# 	 dragonfly is a insect ← ANIMAL be heavy - bodied , strong - fly NOUN that hold their wing horizontally
# 	 dragonfly is a insect ← ANIMAL be hemimetabolous NOUN ; they do not have
# 	 crocodile is a reptile ← ANIMAL be the most social of NOUN .
# 	 crocodile is a reptile ← ANIMAL be also the most vocal of all NOUN , produce a wide variety
# 	 shark is a fish ← ANIMAL be a group of elasmobranch cartilaginous NOUN characterize by a ribless endoskeleton
# 	 lark is a bird ← ANIMAL be passerine NOUN of the family Alaudidae .
# 	 toucan is a bird ← ANIMAL be neotropical NOUN in the family Ramphastidae .
# 	 eagle is a bird ← ANIMAL be large , powerfully - build NOUN of prey , with heavy
# 	 beetle is a insect ← ANIMAL be by far the large order of NOUN : the roughly 400,000 specie
# 	 beetle is a insect ← ANIMAL be most likely the first NOUN to pollinate flower .
# 	 beetle is a insect ← ANIMAL be the most widely eat NOUN , with about 344 specie
# 	 hummingbird is a bird ← ANIMAL be the small mature NOUN , measure 7.5–13   cm
# # of new finds:  1339
# Examples of new finds:
# 	 raccoon is a egg ← ANIMAL be virulent predator of NOUN and hatchling in both bird
# 	 cockroach is a adaptation ← ANIMAL be somewhat generalized insect lack special NOUN ; they have chew mouthpart
# 	 dinosaur is a standpoint ← ANIMAL be varied from taxonomic , morphological and ecological NOUN .
# 	 rat is a good ← ANIMAL be frequently blame for damage food supply and other NOUN , or spread disease .
# 	 bull is a cow ← ANIMAL be much more muscular than NOUN , with thick bone ,
# 	 porcupine is a pet ← ANIMAL be also sometimes keep as exotic NOUN .
# 	 bee is a ant ← ANIMAL be winged insect closely related to wasp and NOUN , know for their role
# 	 elephant is a forest ← ANIMAL be important seed disperser ; african NOUN elephant consume and deposit many
# 	 finch is a area ← ANIMAL be typically inhabitant of well - wooded NOUN , but some can be
# 	 lobster is a roll ← ANIMAL be also use in soup , bisque , lobster NOUN , cappon magro , and
# 	 donkey is a desert ← ANIMAL be adapt to marginal NOUN land .
# 	 okapi is a bud ← ANIMAL be herbivore , feed on tree leave and NOUN , grass , fern ,
# 	 lemur is a term ← ANIMAL be a diverse group of primate in NOUN of morphology and physiology .
# 	 grasshopper is a insect ← ANIMAL be typically ground - dwell NOUN with powerful hind leg which
# 	 anteater is a suborder ← ANIMAL be the four extant mammal specie in the NOUN Vermilingua , commonly know for
# 	 grasshopper is a leg ← ANIMAL be typically ground - dwell insect with powerful hind NOUN which allow they to escape
# 	 skunk is a honeybee ← ANIMAL be one of the primary predator of the NOUN , rely on their thick
# 	 tiger is a kill ← ANIMAL be particularly social at NOUN and a male tiger will
# 	 toucan is a disperser ← ANIMAL be poor NOUN , particularly across water ,
# 	 cat is a leather ← ANIMAL be also use in the international fur trade and NOUN industry for make coat ,
#
# ---------------------------------
#
# Pattern: ANIMAL be * NOUN * .
# # of hits:  4
# Hits:
# 	 dinosaur is a reptile ← ANIMAL be a diverse group of NOUN of the clade Dinosauria .
# 	 lark is a bird ← ANIMAL be passerine NOUN of the family Alaudidae .
# 	 toucan is a bird ← ANIMAL be neotropical NOUN in the family Ramphastidae .
# 	 beetle is a insect ← ANIMAL be most likely the first NOUN to pollinate flower .
# # of new finds:  196
# Examples of new finds:
# 	 wombat is a bounty ← ANIMAL be classify as vermin in 1906 , and a NOUN be introduce in 1925 .
# 	 dolphin is a pressure ← ANIMAL be sensitive to vibration and small NOUN change .
# 	 frog is a branch ← ANIMAL be use in clone research and other NOUN of embryology .
# 	 bear is a family ← ANIMAL be carnivoran mammal of the NOUN Ursidae .
# 	 barracuda is a game ← ANIMAL be popular both as food and NOUN fish .
# 	 termite is a culture ← ANIMAL be consume by people in many different NOUN around the world .
# 	 termite is a order ← ANIMAL be formerly place in the NOUN Isoptera .
# 	 monkey is a program ← ANIMAL be prevalent in numerous book , television NOUN , and movie .
# 	 rat is a mouse ← ANIMAL be typically distinguish from NOUN by their size .
# 	 dugong is a specimen ← ANIMAL be long - live , and the old record NOUN reach age 73 .
# 	 whale is a ship ← ANIMAL be sometimes kill or injure during collision with NOUN or boat .
# 	 llama is a 1800 ← ANIMAL be first import into the US in the late NOUN as zoo exhibit .
# 	 shark is a fin ← ANIMAL be often kill for shark NOUN soup .
# 	 termite is a variety ← ANIMAL be consume by a wide NOUN of predator .
# 	 bat is a exception ← ANIMAL be present throughout the world , with the NOUN of extremely cold region .
# 	 crab is a part ← ANIMAL be very often boil alive as NOUN of the cooking process .
# 	 dolphin is a vibration ← ANIMAL be sensitive to NOUN and small pressure change .
# 	 sloth is a metabolism ← ANIMAL be so name because of their very low NOUN and deliberate movement .
# 	 chicken is a food ← ANIMAL be one of the most efficient source of NOUN for many different purpose .
# 	 barracuda is a fishing ← ANIMAL be often target by sport - NOUN enthusiast .
#
# ---------------------------------
#
# Pattern: ANIMAL be * NOUN * specie
# # of hits:  1
# Hits:
# 	 beetle is a insect ← ANIMAL be by far the large order of NOUN : the roughly 400,000 specie
# 	 beetle is a insect ← ANIMAL be the most widely eat NOUN , with about 344 specie
# # of new finds:  4
# Examples of new finds:
# 	 porpoise is a disturbance ← ANIMAL be very sensitive to anthropogenic NOUN , and be keystone specie
# 	 grasshopper is a eater ← ANIMAL be plant - NOUN , with a few specie
# 	 anteater is a host ← ANIMAL be the primary NOUN for at least four specie
# 	 rhinoceros is a land ← ANIMAL be among the large live NOUN animal , with live specie
#
# ---------------------------------
#
# Pattern: ANIMAL be NOUN *
# # of hits:  5
# Hits:
# 	 horse is a mammal ← ANIMAL be NOUN .
# 	 kangaroo is a marsupial ← ANIMAL be NOUN from the family Macropodidae .
# 	 beetle is a insect ← ANIMAL be NOUN that form the order Coleoptera
# 	 hawk is a bird ← ANIMAL be NOUN of prey of the family
# 	 hummingbird is a bird ← ANIMAL be NOUN native to the Americas and
# # of new finds:  68
# Examples of new finds:
# 	 lemur is a primate ← ANIMAL be NOUN belong to the suborder Strepsirrhini
# 	 chicken is a omnivore ← ANIMAL be NOUN .
# 	 louse is a vector ← ANIMAL be NOUN of disease such as typhus
# 	 wombat is a herbivore ← ANIMAL be NOUN ; their diet consist mostly
# 	 snail is a protostome ← ANIMAL be NOUN .
# 	 hamster is a omnivore ← ANIMAL be NOUN , which mean they can
# 	 peccary is a foregut ← ANIMAL be NOUN fermenter .
# 	 lion is a part ← ANIMAL be NOUN of a group of exotic
# 	 peccary is a pig ← ANIMAL be NOUN - like ungulate of the
# 	 dolphin is a descendant ← ANIMAL be NOUN of land - dwell mammal
# 	 turtle is a reptile ← ANIMAL be NOUN of the order Testudines ,
# 	 elephant is a dichromat ← ANIMAL be NOUN and they can see well
# 	 okapi is a herbivore ← ANIMAL be NOUN , feed on tree leave
# 	 lobster is a invertebrate ← ANIMAL be NOUN with a hard protective exoskeleton
# 	 grasshopper is a plant ← ANIMAL be NOUN - eater , with a
# 	 snake is a polyphyodont ← ANIMAL be NOUN with tooth that be continuously
# 	 crocodile is a ambush ← ANIMAL be NOUN predator , wait for fish
# 	 barracuda is a scavenger ← ANIMAL be NOUN , and may mistake snorkeler
# 	 koala is a hindgut ← ANIMAL be NOUN fermenter , and their digestive
# 	 baboon is a primate ← ANIMAL be NOUN comprise the genus Papio ,
#
# ---------------------------------
#
# Pattern: ANIMAL be NOUN * .
# # of hits:  1
# Hits:
# 	 kangaroo is a marsupial ← ANIMAL be NOUN from the family Macropodidae .
# # of new finds:  5
# Examples of new finds:
# 	 rabbit is a prey ← ANIMAL be NOUN animal .
# 	 skunk is a mammal ← ANIMAL be NOUN in the family Mephitidae .
# 	 spider is a chelicerate ← ANIMAL be NOUN and therefore , arthropod .
# 	 peccary is a foregut ← ANIMAL be NOUN fermenter .
# 	 rhinoceros is a hindgut ← ANIMAL be NOUN fermenter .
#
# ---------------------------------
#
# Pattern: ANIMAL be NOUN * and
# # of hits:  1
# Hits:
# 	 hummingbird is a bird ← ANIMAL be NOUN native to the Americas and
# # of new finds:  0
# Examples of new finds:
# 	None
#
# ---------------------------------
#
# Pattern: ANIMAL be the * NOUN *
# # of hits:  3
# Hits:
# 	 crocodile is a reptile ← ANIMAL be the most social of NOUN .
# 	 beetle is a insect ← ANIMAL be the most widely eat NOUN , with about 344 specie
# 	 hummingbird is a bird ← ANIMAL be the small mature NOUN , measure 7.5–13   cm
# # of new finds:  44
# Examples of new finds:
# 	 anteater is a host ← ANIMAL be the primary NOUN for at least four specie
# 	 hornet is a wasp ← ANIMAL be the large of the eusocial NOUN , and be similar in
# 	 louse is a member ← ANIMAL be the common name for any NOUN of the clade Phthiraptera ,
# 	 lark is a feather ← ANIMAL be the only passerine that lose all their NOUN in their first moult .
# 	 sheep is a mammal ← ANIMAL be the only specie of NOUN except for human which exhibit
# 	 sheep is a specie ← ANIMAL be the only NOUN of mammal except for human
# 	 anteater is a specie ← ANIMAL be the primary host for at least four NOUN of tick : a. nodosum
# 	 lizard is a name ← ANIMAL be the common NOUN use for all squamate reptile
# 	 tarsier is a primate ← ANIMAL be the only entirely carnivorous extant NOUN , albeit mainly insectivorous ,
# 	 anteater is a specie ← ANIMAL be the four extant mammal NOUN in the suborder Vermilingua ,
# 	 dog is a animal ← ANIMAL be the companion NOUN most frequently report for exposure
# 	 parrot is a creature ← ANIMAL be the only NOUN that display true tripedalism ,
# 	 fly is a group ← ANIMAL be the second large NOUN of pollinator after the Hymenoptera
# 	 gorilla is a height ← ANIMAL be the large live primate , reach NOUN between 1.25 and 1.8
# 	 turtle is a distance ← ANIMAL be the only reptile that migrate long NOUN , more specifically the marine
# 	 deer is a animal ← ANIMAL be the principal sacrificial NOUN for the Huichal Indians of
# 	 bat is a flight ← ANIMAL be the only mammal capable of sustained NOUN , as oppose to glide
# 	 beaver is a capybara ← ANIMAL be the second - large live rodent , after NOUN , weigh up to 50
# 	 beaver is a rodent ← ANIMAL be the second - large live NOUN , after capybara .
# 	 human is a animal ← ANIMAL be the only NOUN know to cry emotional tear
#
# ---------------------------------
#
# Pattern: ANIMAL be the * NOUN * specie
# # of hits:  1
# Hits:
# 	 beetle is a insect ← ANIMAL be the most widely eat NOUN , with about 344 specie
# # of new finds:  1
# Examples of new finds:
# 	 anteater is a host ← ANIMAL be the primary NOUN for at least four specie
#
# ---------------------------------
#
# Pattern: ANIMAL be the * NOUN .
# # of hits:  1
# Hits:
# 	 crocodile is a reptile ← ANIMAL be the most social of NOUN .
# # of new finds:  4
# Examples of new finds:
# 	 elephant is a animal ← ANIMAL be the large live land NOUN .
# 	 elephant is a animal ← ANIMAL be the large live terrestrial NOUN .
# 	 human is a tear ← ANIMAL be the only animal know to cry emotional NOUN .
# 	 beaver is a capybara ← ANIMAL be the second - large live rodent , after NOUN .
# 	 hummingbird is a dinosaur ← ANIMAL be the small know and small live avian theropod NOUN .
#
# ---------------------------------
#
# Pattern: like most NOUN , * ANIMAL *
# # of hits:  1
# Hits:
# 	 kangaroo is a marsupial ← like most NOUN , female ANIMAL have a pouch call a
# # of new finds:  5
# Examples of new finds:
# 	 iguana is a reptile ← like most NOUN , an ANIMAL have a three - chambered
# 	 spider is a arachnid ← like most NOUN , include scorpion , ANIMAL have a narrow gut that
# 	 bobcat is a cat ← like most NOUN , the ANIMAL be territorial and largely solitary
# 	 bobcat is a feline ← like most NOUN , the ANIMAL be largely solitary , but
# 	 opossum is a marsupial ← like most NOUN , the male ANIMAL have a fork penis bear
#
# ---------------------------------
#
# Pattern: like most NOUN , ANIMAL * and
# # of hits:  1
# Hits:
# 	 hawk is a bird ← like most NOUN , ANIMAL migrate in the autumn and
# # of new finds:  0
# Examples of new finds:
# 	None
#
# ---------------------------------
#
# Pattern: like most NOUN , ANIMAL * the
# # of hits:  1
# Hits:
# 	 beetle is a insect ← like most NOUN , ANIMAL inhale air , for the
# # of new finds:  0
# Examples of new finds:
# 	None
#
# ---------------------------------
#
# Pattern: like other NOUN , * ANIMAL *
# # of hits:  1
# Hits:
# 	 octopus is a cephalopod ← like other NOUN , an ANIMAL be bilaterally symmetric with two
# # of new finds:  2
# Examples of new finds:
# 	 platypus is a monotreme ← like other NOUN , the ANIMAL have a sense of electrolocation
# 	 fox is a canine ← like other NOUN , the male ANIMAL have a baculum , or
#
# ---------------------------------
#
# Pattern: like other NOUN , ANIMAL *
# # of hits:  5
# Hits:
# 	 dinosaur is a reptile ← like other NOUN , ANIMAL be primarily uricotelic , that
# 	 shark is a fish ← like other NOUN , ANIMAL extract oxygen from seawater as
# 	 anteater is a xenarthan ← like other NOUN , ANIMAL originally evolve in South America
# 	 beetle is a insect ← like other NOUN , ANIMAL have open circulatory system ,
# 	 octopus is a cephalopod ← like other NOUN , ANIMAL have camera - like eye
# # of new finds:  15
# Examples of new finds:
# 	 grasshopper is a insect ← like other NOUN , ANIMAL have an open circulatory system
# 	 ant is a arthropod ← like other NOUN , ANIMAL have an exoskeleton , an
# 	 spider is a arthropod ← like other NOUN , ANIMAL be coelomate in which the
# 	 spider is a arthropod ← like other NOUN , ANIMAL have to molt to grow
# 	 rook is a corvid ← like other NOUN , ANIMAL will sometimes favour site with
# 	 gecko is a reptile ← like other NOUN , ANIMAL be ectothermic , produce very
# 	 raccoon is a predator ← like other NOUN , ANIMAL search for food can break
# 	 cockroach is a insect ← like other NOUN , ANIMAL breathe through a system of
# 	 human is a mammal ← like other NOUN , ANIMAL have an XY sex -
# 	 termite is a insect ← like other NOUN , ANIMAL have a small tongue -
# 	 alpaca is a camelid ← like other NOUN , ANIMAL have a three - chambered
# 	 fish is a animal ← like other NOUN , ANIMAL suffer from parasitism .
# 	 lemur is a primate ← like other NOUN , ANIMAL groom socially to ease tension
# 	 fly is a insect ← like other NOUN , ANIMAL have chemoreceptor that detect smell
# 	 koala is a marsupial ← like other NOUN , ANIMAL give birth to young know
# 	 alligator is a crocodilian ← like other NOUN , ANIMAL have an armor of bony
#
# ---------------------------------
#
# Pattern: like other NOUN , ANIMAL * ,
# # of hits:  1
# Hits:
# 	 beetle is a insect ← like other NOUN , ANIMAL have open circulatory system ,
# # of new finds:  0
# Examples of new finds:
# 	None
#
# ---------------------------------
#
# Pattern: like other NOUN , ANIMAL * as
# # of hits:  1
# Hits:
# 	 shark is a fish ← like other NOUN , ANIMAL extract oxygen from seawater as
# # of new finds:  0
# Examples of new finds:
# 	None
#
# ---------------------------------
#
# Pattern: the ANIMAL be a * NOUN *
# # of hits:  3
# Hits:
# 	 horse is a mammal ← the ANIMAL be a domesticate , one - toed , hoofed NOUN .
# 	 alpaca is a mammal ← the ANIMAL be a species of south american camelid NOUN .
# 	 kinkajou is a mammal ← the ANIMAL be a tropical rainforest NOUN of the family Procyonidae relate
# # of new finds:  108
# Examples of new finds:
# 	 ferret is a species ← the ANIMAL be a small , domesticate NOUN belong to the family Mustelidae
# 	 leopard is a prey ← the ANIMAL be a carnivore that prefer medium - sized NOUN with a body mass range
# 	 tiger is a apex ← the ANIMAL be a carnivore and an NOUN predator feed mainly on large
# 	 hippopotamus is a land ← the ANIMAL be a megaherbivore and be exceed in size among NOUN animal only by elephant and
# 	 walrus is a discontinuous ← the ANIMAL be a large pinniped marine mammal with   NOUN distribution about the North Pole
# 	 heron is a family ← the ANIMAL be a highly mobile NOUN , with most specie be
# 	 chimpanzee is a species ← the ANIMAL be a highly adaptable NOUN .
# 	 dog is a wolf ← the ANIMAL be a domesticate descendant of the gray NOUN .
# 	 leopard is a heraldry ← the ANIMAL be a frequently use motif in NOUN , most commonly as passant
# 	 narwhal is a cetacean ← the ANIMAL be a stocky NOUN with a relatively blunt snout
# 	 impala is a antelope ← the ANIMAL be a medium - sized , slender - bodied NOUN , comparable to the kob
# 	 cougar is a hypercarnivore ← the ANIMAL be a generalist NOUN .
# 	 dog is a descendant ← the ANIMAL be a domesticate NOUN of the gray wolf .
# 	 leopard is a taxon ← the ANIMAL be a sister NOUN to a clade within Panthera
# 	 wolf is a cosmology ← the ANIMAL be a common motif in the mythology and NOUN of people throughout its historical
# 	 meerkat is a mongoose ← the ANIMAL be a small NOUN of slim build characterise by
# 	 dog is a pathway ← the ANIMAL be a domestic animal that likely travel a commensal NOUN into domestication .
# 	 wasp is a thousand ← the ANIMAL be a cosmopolitan paraphyletic grouping of hundred of NOUN of specie , consist of
# 	 rook is a bird ← the ANIMAL be a fairly large NOUN , at 280 to 340
# 	 tiger is a individual ← the ANIMAL be a long - range species and NOUN disperse over distance of up
#
# ---------------------------------
#
# Pattern: the ANIMAL be a * NOUN .
# # of hits:  2
# Hits:
# 	 horse is a mammal ← the ANIMAL be a domesticate , one - toed , hoofed NOUN .
# 	 alpaca is a mammal ← the ANIMAL be a species of south american camelid NOUN .
# # of new finds:  15
# Examples of new finds:
# 	 aardvark is a animal ← the ANIMAL be a rather quiet NOUN .
# 	 hare is a cuisine ← the ANIMAL be a staple of maltese NOUN .
# 	 giraffe is a range ← the ANIMAL be a protect species in most of its NOUN .
# 	 heron is a distribution ← the ANIMAL be a widespread family with a cosmopolitan NOUN .
# 	 cougar is a hypercarnivore ← the ANIMAL be a generalist NOUN .
# 	 cougar is a animal ← the ANIMAL be a mostly solitary NOUN .
# 	 guanaco is a animal ← the ANIMAL be a diurnal NOUN .
# 	 leopard is a animal ← the ANIMAL be a solitary and territorial NOUN .
# 	 cheetah is a animal ← the ANIMAL be a large cat and the fast land NOUN .
# 	 dog is a wolf ← the ANIMAL be a domesticate descendant of the gray NOUN .
# 	 chimpanzee is a species ← the ANIMAL be a highly adaptable NOUN .
# 	 wolf is a animal ← the ANIMAL be a social NOUN .
# 	 jaguar is a animal ← the ANIMAL be a compact and muscular NOUN .
# 	 crane is a mythology ← the ANIMAL be a bird of omen in greek NOUN .
# 	 chamois is a bovid ← the ANIMAL be a very small NOUN .
#
# ---------------------------------
#
# Pattern: unlike other NOUN , * ANIMAL * and
# # of hits:  1
# Hits:
# 	 crocodile is a reptile ← unlike other NOUN , a ANIMAL have a cerebral cortex and
# # of new finds:  0
# Examples of new finds:
# 	None
#
# ---------------------------------
#
# Pattern: unlike other NOUN , ANIMAL *
# # of hits:  2
# Hits:
# 	 shark is a fish ← unlike other NOUN , ANIMAL gill slit be not cover
# 	 camel is a mammal ← unlike other NOUN , ANIMAL ' red blood cell be
# # of new finds:  0
# Examples of new finds:
# 	None
#
# ---------------------------------
#
# Pattern: unlike other NOUN , ANIMAL * be
# # of hits:  1
# Hits:
# 	 camel is a mammal ← unlike other NOUN , ANIMAL ' red blood cell be
# # of new finds:  0
# Examples of new finds:
# 	None
#
# ---------------------------------

# %% [markdown]
# ### To-Do

# %% [markdown]
# > 💡 **Consider**: when inspecting the new finds of each pattern, what do you notice? What patterns are productive, but imprecise? What patterns are precise, but unproductive?

# %% [markdown]
# **Response**: Patterns that are productive but imprecise include ANIMAL , like * NOUN *, ANIMAL be * NOUN *, ANIMAL be * NOUN * ., ANIMAL be NOUN *, ANIMAL be the * NOUN *, and the ANIMAL be a * NOUN *. Patterns that are precise but unproductive include ANIMAL be * NOUN * specie, ANIMAL be NOUN * ., like most NOUN , * ANIMAL *, and like other NOUN , * ANIMAL *. I've also noticed that there were several patterns that had low preciison and low productivity, but there are more patterns that are productive and make many discoveries, but with questionable precision.

# %% [markdown]
# > 💡 **Consider**: Is there a better way than string/phrase matching to capture patterns such as "*This animal preserve includes __mammals__ such as __lions__, __elephants__, and __giraffes__*"? (This [paper](https://papers.nips.cc/paper_files/paper/2004/hash/358aee4cc897452c00244351e4d91f69-Abstract.html) may contain clues.)

# %% [markdown]
# **Response**: Yes. Rather than using Hearst Patterns, which may not capture all of the context here with the multiple animals separated by commas, one may be better off using dependency path features as detailed by the paper, which use a generalization of grammatical patterns to be more effective.

# %% [markdown]
# > 💡 **Consider**: You realize that there are some sentences in the zoologists' notes that are completely missed by your pipeline, such as the second sentence here: "*__Giraffes__ are tall. They are __mammals__.*" What are some ways you might improve your current approach or dataset?

# %% [markdown]
# **Response**: The reason sentences like this get missed is because they do not explicitly name an animal, and the current model does not recognize pronouns. We can improve our current approach using coreference resolution algorithms, which are able to identify exactly what the pronouns refer to.

# %% [markdown]
# > 💡 **Consider**: How might you extract not just ANIMAL → NOUN relations (e.g. "kangaroo" → "marsupial", "kangaroo" → "macropod"), but also NOUN → NOUN relations (e.g. "macropod" → "marsupial") to create a full taxonomy tree?

# %% [markdown]
# **Response**: You could build out a larger tree mapping out more complex hierarchical relationships by changing the strategy for identifying relationships to be more robust and running it through the corpus multiple times.

# %% [markdown]
# # Submission

# %% [markdown]
# Congratulations on finishing HW5! Please ensure that you submit this completed notebook onto Gradescope. Make sure all cells in the notebook are run so that print statements are visible.
#
# `File` --> `Download` --> `Download .ipynb`
#
# Make sure your notebook is named `HW5.ipynb` when you upload it to [Gradescope](https://www.gradescope.com/courses/1238346) before April 6, 2026 at 11:59pm.

# %% [markdown]
# ## Addendum
#
# The list of animals in this homework are drawn from [Wikipedia's list of animal names](https://en.wikipedia.org/wiki/List_of_animal_names), and the zoologists' notes are actually sentences pulled from Wikipedia.
